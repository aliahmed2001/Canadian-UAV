# 31  235 -101.836889 -120.809672
# 32  440  -71.746504   33.095026
# 33  302   83.298005   -3.798804
# 34  522  -15.273000   29.405072
# 35  112  -40.480983   99.069098
# 36  543  -88.603824   42.820766
# 37  763  -62.143606  -69.059316
# 38  709    2.094669  -89.629818
# 39  652   76.911490 -106.471674
# 40   59 -125.324821    6.089719
# 41  219  -74.186856 -122.694218
# 42  287  113.626647   73.594959
# 43  818   85.689943   41.730680
# 44  875 -134.735004  -57.264716

# %%
sen1 =[]
sen2 =[]
for r in range(len(data_a)):
    for t in range(len(data_b)):
        if data_a.iloc[r].Latitude.round() == data_b.iloc[t].Latitude.round():
            if data_a.iloc[r].Longitude.round() == data_b.iloc[t].Longitude.round():
                sen1.append(data_a.iloc[r].Id)
                sen2.append(data_b.iloc[t].Id)
                print()

sen1,sen2
# Out:
# ([763.0,
#   258.0,
#   235.0,
#   56.0,
#   962.0,
#   895.0,
#   440.0,
#   219.0,
#   205.0,
#   196.0,
#   534.0,
#   80.0,
#   543.0,
#   652.0,
#   327.0,
#   542.0,
#   122.0,
#   965.0,
#   287.0,
#   455.0,
#   901.0,
#   232.0,
#   650.0,
#   805.0,
#   599.0,
#   1.0,
#   215.0,
#   818.0,
#   875.0,
#   355.0,
#   522.0,
#   495.0,
#   897.0,
#   59.0,
#   112.0,
#   761.0,
#   924.0,
#   154.0,
#   302.0,
#   473.0],
#  [763.0,
#   258.0,
#   235.0,
#   56.0,
#   962.0,
#   895.0,
#   440.0,
#   219.0,
#   205.0,
#   196.0,
#   534.0,
#   80.0,
#   543.0,
#   652.0,
#   327.0,
#   542.0,
#   122.0,
#   965.0,
#   287.0,
#   455.0,
#   901.0,
#   232.0,
#   650.0,
#   805.0,
#   599.0,
#   1.0,
#   215.0,
#   818.0,
#   875.0,
#   355.0,
#   522.0,
#   495.0,
#   897.0,
#   59.0,
#   112.0,
#   761.0,
#   924.0,
#   154.0,
#   302.0,
#   473.0])

# %%
csv = []
ones_a = []
for w in range(len(data_a)):
    if data_a.iloc[w].Id in sen1:
        print()
    else:
        csv.append(data_a.iloc[w].Id)
        ones_a.append(-1)
csv
# Out:
# [307.0, 836.0, 720.0, 168.0, 640.0]

# %%
rows, cols = (len(csv), 2)
part_a = [[0]*cols]*rows
for e in range(len(csv)):
    part_a[e]=csv[e],ones_a[e] 
    
part_a
# Out:
# [(307.0, -1), (836.0, -1), (720.0, -1), (168.0, -1), (640.0, -1)]

# %%
json = []
ones_b = []
for w in range(len(data_a)):
    if data_b.iloc[w].Id in sen2:
        print()
    else:
        json.append(data_b.iloc[w].Id)
        ones_b.append(-1)
json
# Out:
# [993.0, 246.0, 709.0, 911.0, 709.0]

# %%
rows, cols = (len(csv), 2)
part_b = [[0]*cols]*rows
for e in range(len(json)):
    part_b[e]=ones_b[e],json[e] 
    
part_b
# Out:
# [(-1, 993.0), (-1, 246.0), (-1, 709.0), (-1, 911.0), (-1, 709.0)]

# %%
rows, cols = (len(sen1), 2)
arr = [[0]*cols]*rows
len(sen1)
# Out:
# 40

# %%
for e in range(len(sen1)):
    arr[e]=sen1[e],sen2[e] 
    
arr
# Out:
# [(763.0, 763.0),
#  (258.0, 258.0),
#  (235.0, 235.0),
#  (56.0, 56.0),
#  (962.0, 962.0),
#  (895.0, 895.0),
#  (440.0, 440.0),
#  (219.0, 219.0),
#  (205.0, 205.0),
#  (196.0, 196.0),
#  (534.0, 534.0),
#  (80.0, 80.0),
#  (543.0, 543.0),
#  (652.0, 652.0),
#  (327.0, 327.0),
#  (542.0, 542.0),
#  (122.0, 122.0),
#  (965.0, 965.0),
#  (287.0, 287.0),
#  (455.0, 455.0),
#  (901.0, 901.0),
#  (232.0, 232.0),
#  (650.0, 650.0),
#  (805.0, 805.0),
#  (599.0, 599.0),
#  (1.0, 1.0),
#  (215.0, 215.0),
#  (818.0, 818.0),
#  (875.0, 875.0),
#  (355.0, 355.0),
#  (522.0, 522.0),
#  (495.0, 495.0),
#  (897.0, 897.0),
#  (59.0, 59.0),
#  (112.0, 112.0),
#  (761.0, 761.0),
#  (924.0, 924.0),
#  (154.0, 154.0),
#  (302.0, 302.0),
#  (473.0, 473.0)]

# %%
for r in range(len(part_a)):
    arr.append(part_a[r])
    
for r in range(len(part_b)):
    arr.append(part_b[r])
    
arr
# Out:
# [(763.0, 763.0),
#  (258.0, 258.0),
#  (235.0, 235.0),
#  (56.0, 56.0),
#  (962.0, 962.0),
#  (895.0, 895.0),
#  (440.0, 440.0),
#  (219.0, 219.0),
#  (205.0, 205.0),
#  (196.0, 196.0),
#  (534.0, 534.0),
#  (80.0, 80.0),
#  (543.0, 543.0),
#  (652.0, 652.0),
#  (327.0, 327.0),
#  (542.0, 542.0),
#  (122.0, 122.0),
#  (965.0, 965.0),
#  (287.0, 287.0),
#  (455.0, 455.0),
#  (901.0, 901.0),
#  (232.0, 232.0),
#  (650.0, 650.0),
#  (805.0, 805.0),
#  (599.0, 599.0),
#  (1.0, 1.0),
#  (215.0, 215.0),
#  (818.0, 818.0),
#  (875.0, 875.0),
#  (355.0, 355.0),
#  (522.0, 522.0),
#  (495.0, 495.0),
#  (897.0, 897.0),
#  (59.0, 59.0),
#  (112.0, 112.0),
#  (761.0, 761.0),
#  (924.0, 924.0),
#  (154.0, 154.0),
#  (302.0, 302.0),
#  (473.0, 473.0),
#  (307.0, -1),
#  (836.0, -1),
#  (720.0, -1),
#  (168.0, -1),
#  (640.0, -1),
#  (-1, 993.0),
#  (-1, 246.0),
#  (-1, 709.0),
#  (-1, 911.0),
#  (-1, 709.0)]
